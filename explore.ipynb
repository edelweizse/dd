# %%
import polars as pl

# %%
pl.read_parquet(
  'data/processed/chem_pheno_edges.parquet'
)
# Out:
# shape: (115_159, 4)
# ┌────────────────┬─────────┬────────────┬───────────────────┐
# │ CHEM_PHENO_IDX ┆ CHEM_ID ┆ GO_TERM_ID ┆ PHENO_ACTION_TYPE │
# │ ---            ┆ ---     ┆ ---        ┆ ---               │
# │ u32            ┆ u32     ┆ u32        ┆ i64               │
# ╞════════════════╪═════════╪════════════╪═══════════════════╡
# │ 0              ┆ 3209    ┆ 2112       ┆ 0                 │
# │ 1              ┆ 7600    ┆ 8180       ┆ 0                 │
# │ 2              ┆ 3609    ┆ 1043       ┆ 1                 │
# │ 3              ┆ 4434    ┆ 12406      ┆ 1                 │
# │ 4              ┆ 3837    ┆ 2464       ┆ 1                 │
# │ …              ┆ …       ┆ …          ┆ …                 │
# │ 115154         ┆ 6025    ┆ 2167       ┆ 1                 │
# │ 115155         ┆ 6689    ┆ 12649      ┆ 1                 │
# │ 115156         ┆ 1430    ┆ 3071       ┆ 1                 │
# │ 115157         ┆ 4094    ┆ 6768       ┆ 0                 │
# ...
